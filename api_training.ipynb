# %%
#Working with API

#import libraries
import requests
import pandas as pd
import time
import tweepy as tw

##Youtube

#YT_API_KEY = 'AIzaSyCpw_WEFAF9cccV26yxaIVeGnr2pcXDH1s'
#yt_channel_id = 'UCXDH5u39l-8XfHfIgy5fiQA'

#Make API Call
#pageToken = ''
#yt_url = 'https://www.googleapis.com/youtube/v3/search?key='+YT_API_KEY+'&channelId='+yt_channel_id+'&part=snippet,id&order=viewCount'+pageToken
#response = requests.get(yt_url).json()
#.get() is a function that make API call and grab the data
#response


##Twitter

#keys & tokens
user_key = 'RRcJcbEvuE5ToJfw9mR5KwoqM'
user_secret_key = 'BHmijGf18Wm7imuDd9cqWqg8ZjETSYRcNapwb98QoDqKcNcsgW'
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAFlcbwEAAAAAUvyHN5LvsNchnahu1e%2Ff9XPfZkE%3DcKDeX6Ckly4wsUmO4rmD9gmwlgP0jkBoRGNPGRV1HQDv6JbiNd'

#authenticate
auth = tw.OAuthHandler(user_key, user_secret_key)
api = tw.API(auth,wait_on_rate_limit=True)

#query
search_query = '#covid19 -filter:retweets'

#get tweets
c19_tweets = tw.Cursor(api.search_tweets,
                      q=search_query,
                      lang='en',
                      since='2022-05-09').items(50)

#store API responses in list
tweets_copy =[]
for tweet in c19_tweets:
    tweets_copy.append(tweet)
    
print('Total tweets about Covid-29 since May 9th 2022 fetched:', len(tweets_copy))

#initializing dataframe
c19_tweets_df = pd.DataFrame()

for tweet in tweets_copy:
    hashtags = []
    try:
        for hastag in tweet.entities['hashtags']:
            hastags.append(hashtags['text'])
        text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
    except:
        pass
    c19_tweets_df = c19_tweets_df.append(pd.DataFrame({'user_name':tweet.user.name,
                                              'user_location':tweet.user.location,
                                              'user_description':tweet.user.description,
                                              'date':tweet.created_at,
                                              'text':text,
                                              'hastags':[hashtags if hashtags else None],
                                              'source':tweet.source}))

c19_tweets_df = c19_tweets_df.reset_index(drop=True)

#c19_tweets_df.head()

c19_tweets_df
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# ...
